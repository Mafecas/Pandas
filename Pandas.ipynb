# %% [markdown]
# <a href="https://colab.research.google.com/github/Mafecas/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #crear una serie: columna de un datafram (columna)
# Arreglo unidimensional de datos

# %%
miSerie=pd.Series([4,56,78,23,34])
print(miSerie)
# Out:
# 0     4
# 1    56
# 2    78
# 3    23
# 4    34
# dtype: int64

# %% [markdown]
# #Diccionario de python
# Estructura que guarda datos en forma de objetos llave-valor

# %%
miDiccionario=miDiccionario = (
    {
    "nombre": "Casa",
    "área": 120,
    "baños": 3,
    "propietarios": [
        "Paulo", "Diana", "Sonia"
    ],
    "barrio": {
        "nombre": "Gran Britalia",
        "localidad": "Bosa"
}
    }

)
miDiccionario
# Out:
# {'nombre': 'Casa',
#  'área': 120,
#  'baños': 3,
#  'propietarios': ['Paulo', 'Diana', 'Sonia'],
#  'barrio': {'nombre': 'Gran Britalia', 'localidad': 'Bosa'}}

# %% [markdown]
# #DataFrame
# Estructura de datos en forma de tabla
# la forma de crear un dataframe es a partir de un diccionario, otra forma puede ser desde hojas de calculo, desde archivo JSON o desdearchivo CSV (valores separados por coma)

# %%
miDataframe=pd.DataFrame ({"si":[10,15],"No":[50,68]})
miDataframe
# Out:
#    si  No
# 0  10  50
# 1  15  68

# %% [markdown]
# #Cargar Archivos CSV en un Dataframe

# %%
#Leer el archivo CSV
miCSV=pd.read_csv("Datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1  Estudiante_2  Estudiante_3
# 0            34            23            45
# 1            45            10            46
# 2            25            30            46

# %%
miTitanic=pd.read_csv("titanic.CSV")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miRick=pd.read_csv("RickAndMortyScripts.csv")
miRick.shape
miRick.head()
# Out:
#    index  season no.  episode no. episode name   name  \
# 0      0           1            1        Pilot   Rick
# 1      1           1            1        Pilot  Morty
# 2      2           1            1        Pilot   Rick
# 3      3           1            1        Pilot  Morty
# 4      4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
miRick.describe()
# Out:
#             indice   season no.  episode no.
# count  1905.000000  1905.000000  1905.000000
# mean   1190.003675     2.155381     3.208399
# std     721.719735     0.832004     2.247812
# min       0.000000     1.000000     1.000000
# 25%     548.000000     1.000000     1.000000
# 50%    1164.000000     2.000000     3.000000
# 75%    1844.000000     3.000000     5.000000
# max    2487.000000     3.000000    10.000000

# %%
miRick.rename(columns={"index":"indice"},inplace=True)

# %%
miRick.head()
# Out:
#    indice  season no.  episode no. episode name   name  \
# 0       0           1            1        Pilot   Rick
# 1       1           1            1        Pilot  Morty
# 2       2           1            1        Pilot   Rick
# 3       3           1            1        Pilot  Morty
# 4       4           1            1        Pilot   Rick
#
#                                                 line
# 0  Morty! You gotta come on. Jus'... you gotta co...
# 1                       What, Rick? What’s going on?
# 2                   I got a surprise for you, Morty.
# 3  It's the middle of the night. What are you tal...
# 4  Come on, I got a surprise for you.  Come on, h...

# %%
misIndice=miRick["indice"]
misIndice.count()
# Out:
# 1905

# %%
misIndice.product()
# Out:
# 0

# %% [markdown]
# #Seleccionar filas especificas (Filtrar filas)

# %%
miRickFiltrado=miRick[misIndice>0]
miRickFiltrado.count()
# Out:
# indice          1904
# season no.      1904
# episode no.     1904
# episode name    1904
# name            1904
# line            1904
# dtype: int64

# %%
miTitanic=pd.read_csv("titanic.CSV")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#Sumar todos los sobrevivientes del Titanic
miTitanic.rename(columns={"Survived":"Sobrevivientes"},inplace=True)
miTitanic.head()
# Out:
#    PassengerId  Sobrevivientes
# 0          892               0
# 1          893               0
# 2          894               0
# 3          895               0
# 4          896               1

# %%
miTitanicFiltrado=miTitanic["Sobrevivientes"]
miTitanicFiltrado.sum()
# Out:
# 153
